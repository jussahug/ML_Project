# %% [markdown]
# # Import các thư viện cần thiết

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.ensemble import RandomForestClassifier
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint
import joblib

# %% [markdown]
# # Import data

# %%
# from google.colab import drive
# drive.mount('/content/gdrive')
# %cd '/content/gdrive/MyDrive/Project'
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/MyDrive/Project

# %%
# !pip install ucimlrepo
from ucimlrepo import fetch_ucirepo

# fetch dataset
predict_students_dropout_and_academic_success = fetch_ucirepo(id=697)

# data (as pandas dataframes)
X = predict_students_dropout_and_academic_success.data.features
y = predict_students_dropout_and_academic_success.data.targets

# metadata
print(predict_students_dropout_and_academic_success.metadata)

# variable information
print(predict_students_dropout_and_academic_success.variables)
# Out:
# Collecting ucimlrepo
#   Downloading ucimlrepo-0.0.7-py3-none-any.whl (8.0 kB)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ucimlrepo) (2.0.3)
# Requirement already satisfied: certifi>=2020.12.5 in /usr/local/lib/python3.10/dist-packages (from ucimlrepo) (2024.7.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->ucimlrepo) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->ucimlrepo) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->ucimlrepo) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->ucimlrepo) (1.25.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->ucimlrepo) (1.16.0)
# Installing collected packages: ucimlrepo
# Successfully installed ucimlrepo-0.0.7
# {'uci_id': 697, 'name': "Predict Students' Dropout and Academic Success", 'repository_url': 'https://archive.ics.uci.edu/dataset/697/predict+students+dropout+and+academic+success', 'data_url': 'https://archive.ics.uci.edu/static/public/697/data.csv', 'abstract': "A dataset created from a higher education institution (acquired from several disjoint databases) related to students enrolled in different undergraduate degrees, such as agronomy, design, education, nursing, journalism, management, social service, and technologies.\nThe dataset includes information known at the time of student enrollment (academic path, demographics, and social-economic factors) and the students' academic performance at the end of the first and second semesters. \nThe data is used to build classification models to predict students' dropout and academic sucess. The problem is formulated as a three category classification task, in which there is a strong imbalance towards one of the classes.", 'area': 'Social Science', 'tasks': ['Classification'], 'characteristics': ['Tabular'], 'num_instances': 4424, 'num_features': 36, 'feature_types': ['Real', 'Categorical', 'Integer'], 'demographics': ['Marital Status', 'Education Level', 'Nationality', 'Occupation', 'Gender', 'Age'], 'target_col': ['Target'], 'index_col': None, 'has_missing_values': 'no', 'missing_values_symbol': None, 'year_of_dataset_creation': 2021, 'last_updated': 'Mon Feb 26 2024', 'dataset_doi': '10.24432/C5MC89', 'creators': ['Valentim Realinho', 'Mónica Vieira Martins', 'Jorge Machado', 'Luís Baptista'], 'intro_paper': {'title': "Early prediction of student's performance in higher education: a case study", 'authors': 'Mónica V. Martins, Daniel Tolledo, Jorge Machado, Luís M. T. Baptista, and Valentim Realinho', 'published_in': 'Trends and Applications in Information Systems and Technologies', 'year': 2021, 'url': 'http://www.worldcist.org/2021/', 'doi': 'http://www.doi.org/10.1007/978-3-030-72657-7_16'}, 'additional_info': {'summary': None, 'purpose': 'The dataset was created in a project that aims to contribute to the reduction of academic dropout and failure in higher education, by using machine learning techniques to identify students at risk at an early stage of their academic path, so that strategies to support them can be put into place. \n\nThe dataset includes information known at the time of student enrollment – academic path, demographics, and social-economic factors. \n\nThe problem is formulated as a three category classification task (dropout, enrolled, and graduate) at the end of the normal duration of the course. \n', 'funded_by': 'This dataset is supported by program SATDAP - Capacitação da Administração Pública under grant POCI-05-5762-FSE-000191, Portugal.', 'instances_represent': 'Each instance is a student', 'recommended_data_splits': 'The dataset was used, in our project, with a data split of 80% for training and 20% for test.', 'sensitive_data': None, 'preprocessing_description': 'We performed a rigorous data preprocessing to handle data from anomalies, unexplainable outliers, and missing values.', 'variable_info': None, 'citation': 'If you use this dataset in experiments for a scientific publication, please kindly cite our paper: \nM.V.Martins, D. Tolledo, J. Machado, L. M.T. Baptista, V.Realinho. (2021) "Early prediction of student’s performance in higher education: a case study" Trends and Applications in Information Systems and Technologies, vol.1, in Advances in Intelligent Systems and Computing series. Springer. DOI: 10.1007/978-3-030-72657-7_16'}}
#                                               name     role         type  \
# 0                                   Marital Status  Feature      Integer
# 1                                 Application mode  Feature      Integer
# 2                                Application order  Feature      Integer
# 3                                           Course  Feature      Integer
# 4                       Daytime/evening attendance  Feature      Integer
# 5                           Previous qualification  Feature      Integer
# 6                   Previous qualification (grade)  Feature   Continuous
# 7                                      Nacionality  Feature      Integer
# 8                           Mother's qualification  Feature      Integer
# 9                           Father's qualification  Feature      Integer
# 10                             Mother's occupation  Feature      Integer
# 11                             Father's occupation  Feature      Integer
# 12                                 Admission grade  Feature   Continuous
# 13                                       Displaced  Feature      Integer
# 14                       Educational special needs  Feature      Integer
# 15                                          Debtor  Feature      Integer
# 16                         Tuition fees up to date  Feature      Integer
# 17                                          Gender  Feature      Integer
# 18                              Scholarship holder  Feature      Integer
# 19                               Age at enrollment  Feature      Integer
# 20                                   International  Feature      Integer
# 21             Curricular units 1st sem (credited)  Feature      Integer
# 22             Curricular units 1st sem (enrolled)  Feature      Integer
# 23          Curricular units 1st sem (evaluations)  Feature      Integer
# 24             Curricular units 1st sem (approved)  Feature      Integer
# 25                Curricular units 1st sem (grade)  Feature      Integer
# 26  Curricular units 1st sem (without evaluations)  Feature      Integer
# 27             Curricular units 2nd sem (credited)  Feature      Integer
# 28             Curricular units 2nd sem (enrolled)  Feature      Integer
# 29          Curricular units 2nd sem (evaluations)  Feature      Integer
# 30             Curricular units 2nd sem (approved)  Feature      Integer
# 31                Curricular units 2nd sem (grade)  Feature      Integer
# 32  Curricular units 2nd sem (without evaluations)  Feature      Integer
# 33                               Unemployment rate  Feature   Continuous
# 34                                  Inflation rate  Feature   Continuous
# 35                                             GDP  Feature   Continuous
# 36                                          Target   Target  Categorical
#
#         demographic                                        description units  \
# 0    Marital Status  1 – single 2 – married 3 – widower 4 – divorce...  None
# 1              None  1 - 1st phase - general contingent 2 - Ordinan...  None
# 2              None  Application order (between 0 - first choice; a...  None
# 3              None  33 - Biofuel Production Technologies 171 - Ani...  None
# 4              None                            1 – daytime 0 - evening  None
# 5   Education Level  1 - Secondary education 2 - Higher education -...  None
# 6              None  Grade of previous qualification (between 0 and...  None
# 7       Nationality  1 - Portuguese; 2 - German; 6 - Spanish; 11 - ...  None
# 8   Education Level  1 - Secondary Education - 12th Year of Schooli...  None
# 9   Education Level  1 - Secondary Education - 12th Year of Schooli...  None
# 10       Occupation  0 - Student 1 - Representatives of the Legisla...  None
# 11       Occupation  0 - Student 1 - Representatives of the Legisla...  None
# 12             None                Admission grade (between 0 and 200)  None
# 13             None                                     1 – yes 0 – no  None
# 14             None                                     1 – yes 0 – no  None
# 15             None                                     1 – yes 0 – no  None
# 16             None                                     1 – yes 0 – no  None
# 17           Gender                                1 – male 0 – female  None
# 18             None                                     1 – yes 0 – no  None
# 19              Age                       Age of studend at enrollment  None
# 20             None                                     1 – yes 0 – no  None
# 21             None  Number of curricular units credited in the 1st...  None
# 22             None  Number of curricular units enrolled in the 1st...  None
# 23             None  Number of evaluations to curricular units in t...  None
# 24             None  Number of curricular units approved in the 1st...  None
# 25             None  Grade average in the 1st semester (between 0 a...  None
# 26             None  Number of curricular units without evalutions ...  None
# 27             None  Number of curricular units credited in the 2nd...  None
# 28             None  Number of curricular units enrolled in the 2nd...  None
# 29             None  Number of evaluations to curricular units in t...  None
# 30             None  Number of curricular units approved in the 2nd...  None
# 31             None  Grade average in the 2nd semester (between 0 a...  None
# 32             None  Number of curricular units without evalutions ...  None
# 33             None                              Unemployment rate (%)  None
# 34             None                                 Inflation rate (%)  None
# 35             None                                                GDP  None
# 36             None  Target. The problem is formulated as a three c...  None
#
#    missing_values
# 0              no
# 1              no
# 2              no
# 3              no
# 4              no
# 5              no
# 6              no
# 7              no
# 8              no
# 9              no
# 10             no
# 11             no
# 12             no
# 13             no
# 14             no
# 15             no
# 16             no
# 17             no
# 18             no
# 19             no
# 20             no
# 21             no
# 22             no
# 23             no
# 24             no
# 25             no
# 26             no
# 27             no
# 28             no
# 29             no
# 30             no
# 31             no
# 32             no
# 33             no
# 34             no
# 35             no
# 36             no

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train)
y_test = label_encoder.transform(y_test)

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

print("Shape of y_train (after to_categorical):", y_train.shape)
print("Shape of y_test (after to_categorical):", y_test.shape)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=1)
# Out:
# Shape of y_train (after to_categorical): (3096, 3)
# Shape of y_test (after to_categorical): (1328, 3)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)

# %% [markdown]
# ## Apply Neurol Network

# %%
model = Sequential()
model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dense(3, activation='softmax'))


model.summary()

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

checkpoint_filepath = 'best_model.h5'
model_checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)

history = model.fit(X_train, y_train, batch_size=256, epochs=120, validation_data=(X_val, y_val), callbacks=[model_checkpoint_callback])

best_model = keras.models.load_model(checkpoint_filepath)

y_pred = best_model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_test_classes = np.argmax(y_test, axis=1)

accuracy = accuracy_score(y_test_classes, y_pred_classes)
precision = precision_score(y_test_classes, y_pred_classes, average='weighted')
recall = recall_score(y_test_classes, y_pred_classes, average='weighted')
f1 = f1_score(y_test_classes, y_pred_classes, average='weighted')

score = best_model.evaluate(X_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
print('Accuracy:', accuracy)
print('Precision:', precision)
print('Recall:', recall)
print('F1 Score:', f1)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 64)                2368
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_7 (Dense)             (None, 64)                4160
#
#  dense_8 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 6723 (26.26 KB)
# Trainable params: 6723 (26.26 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/120
# 11/11 [==============================] - 1s 29ms/step - loss: 1.0841 - accuracy: 0.4555 - val_loss: 0.9161 - val_accuracy: 0.6484
# Epoch 2/120
# 11/11 [==============================] - 0s 10ms/step - loss: 0.9452 - accuracy: 0.6019 - val_loss: 0.8302 - val_accuracy: 0.6839
# Epoch 3/120
# 11/11 [==============================] - 0s 9ms/step - loss: 0.8824 - accuracy: 0.6533 - val_loss: 0.7632 - val_accuracy: 0.7065
# Epoch 4/120
# 11/11 [==============================] - 0s 10ms/step - loss: 0.8265 - accuracy: 0.6572 - val_loss: 0.7175 - val_accuracy: 0.7161
# Epoch 5/120
# 11/11 [==============================] - 0s 9ms/step - loss: 0.8071 - accuracy: 0.6673 - val_loss: 0.6878 - val_accuracy: 0.7258
# Epoch 6/120
# 11/11 [==============================] - 0s 10ms/step - loss: 0.7539 - accuracy: 0.6989 - val_loss: 0.6633 - val_accuracy: 0.7323
# Epoch 7/120
# 11/11 [==============================] - 0s 11ms/step - loss: 0.7380 - accuracy: 0.6967 - val_loss: 0.6462 - val_accuracy: 0.7355
# Epoch 8/120
# 11/11 [==============================] - 0s 9ms/step - loss: 0.7240 - accuracy: 0.7078 - val_loss: 0.6338 - val_accuracy: 0.7419
# Epoch 9/120
# 11/11 [==============================] - 0s 8ms/step - loss: 0.7187 - accuracy: 0.7121 - val_loss: 0.6229 - val_accuracy: 0.7484
# Epoch 10/120
# 11/11 [==============================] - 0s 7ms/step - loss: 0.6925 - accuracy: 0.7164 - val_loss: 0.6133 - val_accuracy: 0.7419
# Epoch 11/120
# 11/11 [==============================] - 0s 8ms/step - loss: 0.7035 - accuracy: 0.7204 - val_loss: 0.6052 - val_accuracy: 0.7548
# Epoch 12/120
# 11/11 [==============================] - 0s 6ms/step - loss: 0.6745 - accuracy: 0.7276 - val_loss: 0.5986 - val_accuracy: 0.7516
# Epoch 13/120
# 11/11 [==============================] - 0s 6ms/step - loss: 0.6734 - accuracy: 0.7337 - val_loss: 0.5914 - val_accuracy: 0.7548
# Epoch 14/120
# 11/11 [==============================] - 0s 9ms/step - loss: 0.6599 - accuracy: 0.7362 - val_loss: 0.5861 - val_accuracy: 0.7581
# Epoch 15/120
# 11/11 [==============================] - 0s 6ms/step - loss: 0.6516 - accuracy: 0.7383 - val_loss: 0.5823 - val_accuracy: 0.7581
# Epoch 16/120
# 11/11 [==============================] - 0s 7ms/step - loss: 0.6558 - accuracy: 0.7387 - val_loss: 0.5776 - val_accuracy: 0.7581
# Epoch 17/120
# 11/11 [==============================] - 0s 9ms/step - loss: 0.6431 - accuracy: 0.7459 - val_loss: 0.5729 - val_accuracy: 0.7516
# Epoch 18/120
# 11/11 [==============================] - 0s 10ms/step - loss: 0.6423 - accuracy: 0.7373 - val_loss: 0.5692 - val_accuracy: 0.7613
# Epoch 19/120
# 11/11 [==============================] - 0s 16ms/step - loss: 0.6225 - accuracy: 0.7538 - val_loss: 0.5673 - val_accuracy: 0.7677
# Epoch 20/120
# 11/11 [==============================] - 0s 13ms/step - loss: 0.6307 - accuracy: 0.7459 - val_loss: 0.5627 - val_accuracy: 0.7677
# Epoch 21/120
# 11/11 [==============================] - 0s 12ms/step - loss: 0.6300 - accuracy: 0.7509 - val_loss: 0.5599 - val_accuracy: 0.7581
# Epoch 22/120
# 11/11 [==============================] - 0s 10ms/step - loss: 0.6197 - accuracy: 0.7548 - val_loss: 0.5574 - val_accuracy: 0.7548
# Epoch 23/120
# 11/11 [==============================] - 0s 12ms/step - loss: 0.6227 - accuracy: 0.7437 - val_loss: 0.5572 - val_accuracy: 0.7645
# Epoch 24/120
# 11/11 [==============================] - 0s 14ms/step - loss: 0.6042 - accuracy: 0.7552 - val_loss: 0.5557 - val_accuracy: 0.7710
# Epoch 25/120
# 11/11 [==============================] - 0s 18ms/step - loss: 0.6081 - accuracy: 0.7523 - val_loss: 0.5541 - val_accuracy: 0.7774
# Epoch 26/120
# 11/11 [==============================] - 0s 14ms/step - loss: 0.6087 - accuracy: 0.7498 - val_loss: 0.5539 - val_accuracy: 0.7774
# Epoch 27/120
# 11/11 [==============================] - 1s 56ms/step - loss: 0.5963 - accuracy: 0.7649 - val_loss: 0.5521 - val_accuracy: 0.7806
# Epoch 28/120
# 11/11 [==============================] - 0s 14ms/step - loss: 0.5951 - accuracy: 0.7588 - val_loss: 0.5506 - val_accuracy: 0.7710
# Epoch 29/120
# 11/11 [==============================] - 0s 9ms/step - loss: 0.5999 - accuracy: 0.7620 - val_loss: 0.5484 - val_accuracy: 0.7710
# Epoch 30/120
# 11/11 [==============================] - 0s 10ms/step - loss: 0.5846 - accuracy: 0.7656 - val_loss: 0.5511 - val_accuracy: 0.7742
# Epoch 31/120
# 11/11 [==============================] - 0s 10ms/step - loss: 0.5889 - accuracy: 0.7674 - val_loss: 0.5504 - val_accuracy: 0.7710
# Epoch 32/120
# 11/11 [==============================] - 0s 11ms/step - loss: 0.5913 - accuracy: 0.7631 - val_loss: 0.5488 - val_accuracy: 0.7742
# Epoch 33/120
# 11/11 [==============================] - 0s 10ms/step - loss: 0.5970 - accuracy: 0.7584 - val_loss: 0.5484 - val_accuracy: 0.7742
# Epoch 34/120
# 11/11 [==============================] - 0s 12ms/step - loss: 0.5796 - accuracy: 0.7685 - val_loss: 0.5468 - val_accuracy: 0.7742
# Epoch 35/120
# 11/11 [==============================] - 0s 14ms/step - loss: 0.5832 - accuracy: 0.7656 - val_loss: 0.5476 - val_accuracy: 0.7839
# Epoch 36/120
# 11/11 [==============================] - 0s 11ms/step - loss: 0.5897 - accuracy: 0.7581 - val_loss: 0.5493 - val_accuracy: 0.7774
# Epoch 37/120
# 11/11 [==============================] - 0s 12ms/step - loss: 0.5819 - accuracy: 0.7699 - val_loss: 0.5489 - val_accuracy: 0.7710
# Epoch 38/120
# 11/11 [==============================] - 0s 10ms/step - loss: 0.5677 - accuracy: 0.7678 - val_loss: 0.5469 - val_accuracy: 0.7742
# Epoch 39/120
# 11/11 [==============================] - 0s 11ms/step - loss: 0.5748 - accuracy: 0.7739 - val_loss: 0.5462 - val_accuracy: 0.7677
# Epoch 40/120
# 11/11 [==============================] - 0s 7ms/step - loss: 0.5765 - accuracy: 0.7638 - val_loss: 0.5427 - val_accuracy: 0.7677
# Epoch 41/120
# 11/11 [==============================] - 0s 8ms/step - loss: 0.5694 - accuracy: 0.7710 - val_loss: 0.5437 - val_accuracy: 0.7806
# Epoch 42/120
# 11/11 [==============================] - 0s 6ms/step - loss: 0.5732 - accuracy: 0.7688 - val_loss: 0.5418 - val_accuracy: 0.7774
# Epoch 43/120
# 11/11 [==============================] - 0s 8ms/step - loss: 0.5696 - accuracy: 0.7717 - val_loss: 0.5432 - val_accuracy: 0.7710
# Epoch 44/120
# 11/11 [==============================] - 0s 8ms/step - loss: 0.5665 - accuracy: 0.7692 - val_loss: 0.5440 - val_accuracy: 0.7839
# Epoch 45/120
# 11/11 [==============================] - 0s 7ms/step - loss: 0.5690 - accuracy: 0.7717 - val_loss: 0.5436 - val_accuracy: 0.7677
# Epoch 46/120
# 11/11 [==============================] - 0s 7ms/step - loss: 0.5761 - accuracy: 0.7670 - val_loss: 0.5400 - val_accuracy: 0.7710
# Epoch 47/120
# 11/11 [==============================] - 0s 7ms/step - loss: 0.5658 - accuracy: 0.7710 - val_loss: 0.5373 - val_accuracy: 0.7742
# Epoch 48/120
# 11/11 [==============================] - 0s 8ms/step - loss: 0.5614 - accuracy: 0.7728 - val_loss: 0.5355 - val_accuracy: 0.7742
# Epoch 49/120
# 11/11 [==============================] - 0s 8ms/step - loss: 0.5545 - accuracy: 0.7753 - val_loss: 0.5342 - val_accuracy: 0.7839
# Epoch 50/120
# 11/11 [==============================] - 0s 9ms/step - loss: 0.5519 - accuracy: 0.7760 - val_loss: 0.5334 - val_accuracy: 0.7774
# Epoch 51/120
# 11/11 [==============================] - 0s 6ms/step - loss: 0.5587 - accuracy: 0.7796 - val_loss: 0.5313 - val_accuracy: 0.7774
# Epoch 52/120
# 11/11 [==============================] - 0s 8ms/step - loss: 0.5425 - accuracy: 0.7832 - val_loss: 0.5322 - val_accuracy: 0.7806
# Epoch 53/120
# 11/11 [==============================] - 0s 6ms/step - loss: 0.5504 - accuracy: 0.7771 - val_loss: 0.5314 - val_accuracy: 0.7774
# Epoch 54/120
# 11/11 [==============================] - 0s 8ms/step - loss: 0.5581 - accuracy: 0.7760 - val_loss: 0.5321 - val_accuracy: 0.7774
# Epoch 55/120
# 11/11 [==============================] - 0s 7ms/step - loss: 0.5572 - accuracy: 0.7735 - val_loss: 0.5355 - val_accuracy: 0.7774
# Epoch 56/120
# 11/11 [==============================] - 0s 8ms/step - loss: 0.5417 - accuracy: 0.7807 - val_loss: 0.5319 - val_accuracy: 0.7774
# Epoch 57/120
# 11/11 [==============================] - 0s 8ms/step - loss: 0.5452 - accuracy: 0.7717 - val_loss: 0.5343 - val_accuracy: 0.7806
# Epoch 58/120
# 11/11 [==============================] - 0s 9ms/step - loss: 0.5392 - accuracy: 0.7854 - val_loss: 0.5361 - val_accuracy: 0.7839
# Epoch 59/120
# 11/11 [==============================] - 0s 9ms/step - loss: 0.5458 - accuracy: 0.7864 - val_loss: 0.5341 - val_accuracy: 0.7806
# Epoch 60/120
# 11/11 [==============================] - 0s 7ms/step - loss: 0.5401 - accuracy: 0.7900 - val_loss: 0.5333 - val_accuracy: 0.7806
# Epoch 61/120
# 11/11 [==============================] - 0s 8ms/step - loss: 0.5384 - accuracy: 0.7897 - val_loss: 0.5360 - val_accuracy: 0.7774
# Epoch 62/120
# 11/11 [==============================] - 0s 9ms/step - loss: 0.5429 - accuracy: 0.7825 - val_loss: 0.5318 - val_accuracy: 0.7839
# Epoch 63/120
# 11/11 [==============================] - 0s 10ms/step - loss: 0.5443 - accuracy: 0.7825 - val_loss: 0.5330 - val_accuracy: 0.7871
# Epoch 64/120
# 11/11 [==============================] - 0s 8ms/step - loss: 0.5405 - accuracy: 0.7821 - val_loss: 0.5321 - val_accuracy: 0.7903
# Epoch 65/120
# 11/11 [==============================] - 0s 8ms/step - loss: 0.5327 - accuracy: 0.7947 - val_loss: 0.5323 - val_accuracy: 0.7806
# Epoch 66/120
# 11/11 [==============================] - 0s 6ms/step - loss: 0.5336 - accuracy: 0.7850 - val_loss: 0.5320 - val_accuracy: 0.7839
# Epoch 67/120
# 11/11 [==============================] - 0s 8ms/step - loss: 0.5330 - accuracy: 0.7889 - val_loss: 0.5318 - val_accuracy: 0.7871
# Epoch 68/120
# 11/11 [==============================] - 0s 7ms/step - loss: 0.5429 - accuracy: 0.7846 - val_loss: 0.5286 - val_accuracy: 0.7806
# Epoch 69/120
# 11/11 [==============================] - 0s 9ms/step - loss: 0.5389 - accuracy: 0.7803 - val_loss: 0.5327 - val_accuracy: 0.7774
# Epoch 70/120
# 11/11 [==============================] - 0s 7ms/step - loss: 0.5311 - accuracy: 0.7836 - val_loss: 0.5314 - val_accuracy: 0.7806
# Epoch 71/120
# 11/11 [==============================] - 0s 8ms/step - loss: 0.5287 - accuracy: 0.7886 - val_loss: 0.5289 - val_accuracy: 0.7871
# Epoch 72/120
# 11/11 [==============================] - 0s 8ms/step - loss: 0.5262 - accuracy: 0.7872 - val_loss: 0.5297 - val_accuracy: 0.7774
# Epoch 73/120
# 11/11 [==============================] - 0s 10ms/step - loss: 0.5279 - accuracy: 0.7900 - val_loss: 0.5301 - val_accuracy: 0.7935
# Epoch 74/120
# 11/11 [==============================] - 0s 6ms/step - loss: 0.5331 - accuracy: 0.7854 - val_loss: 0.5340 - val_accuracy: 0.7774
# Epoch 75/120
# 11/11 [==============================] - 0s 6ms/step - loss: 0.5324 - accuracy: 0.7925 - val_loss: 0.5372 - val_accuracy: 0.7806
# Epoch 76/120
# 11/11 [==============================] - 0s 8ms/step - loss: 0.5265 - accuracy: 0.7940 - val_loss: 0.5345 - val_accuracy: 0.7806
# Epoch 77/120
# 11/11 [==============================] - 0s 6ms/step - loss: 0.5176 - accuracy: 0.7958 - val_loss: 0.5357 - val_accuracy: 0.7806
# Epoch 78/120
# 11/11 [==============================] - 0s 6ms/step - loss: 0.5307 - accuracy: 0.7947 - val_loss: 0.5380 - val_accuracy: 0.7774
# Epoch 79/120
# 11/11 [==============================] - 0s 8ms/step - loss: 0.5407 - accuracy: 0.7872 - val_loss: 0.5371 - val_accuracy: 0.7839
# Epoch 80/120
# 11/11 [==============================] - 0s 8ms/step - loss: 0.5178 - accuracy: 0.7958 - val_loss: 0.5398 - val_accuracy: 0.7806
# Epoch 81/120
# 11/11 [==============================] - 0s 8ms/step - loss: 0.5298 - accuracy: 0.7864 - val_loss: 0.5369 - val_accuracy: 0.7839
# Epoch 82/120
# 11/11 [==============================] - 0s 6ms/step - loss: 0.5238 - accuracy: 0.7925 - val_loss: 0.5319 - val_accuracy: 0.7839
# Epoch 83/120
# 11/11 [==============================] - 0s 8ms/step - loss: 0.5196 - accuracy: 0.7879 - val_loss: 0.5355 - val_accuracy: 0.7806
# Epoch 84/120
# 11/11 [==============================] - 0s 8ms/step - loss: 0.5229 - accuracy: 0.7886 - val_loss: 0.5403 - val_accuracy: 0.7774
# Epoch 85/120
# 11/11 [==============================] - 0s 7ms/step - loss: 0.5150 - accuracy: 0.8004 - val_loss: 0.5384 - val_accuracy: 0.7774
# Epoch 86/120
# 11/11 [==============================] - 0s 8ms/step - loss: 0.5229 - accuracy: 0.7843 - val_loss: 0.5408 - val_accuracy: 0.7806
# Epoch 87/120
# 11/11 [==============================] - 0s 6ms/step - loss: 0.5213 - accuracy: 0.7933 - val_loss: 0.5380 - val_accuracy: 0.7742
# Epoch 88/120
# 11/11 [==============================] - 0s 6ms/step - loss: 0.5132 - accuracy: 0.7925 - val_loss: 0.5386 - val_accuracy: 0.7710
# Epoch 89/120
# 11/11 [==============================] - 0s 6ms/step - loss: 0.5158 - accuracy: 0.7950 - val_loss: 0.5378 - val_accuracy: 0.7710
# Epoch 90/120
# 11/11 [==============================] - 0s 8ms/step - loss: 0.5212 - accuracy: 0.7907 - val_loss: 0.5389 - val_accuracy: 0.7710
# Epoch 91/120
# 11/11 [==============================] - 0s 8ms/step - loss: 0.5043 - accuracy: 0.7918 - val_loss: 0.5381 - val_accuracy: 0.7774
# Epoch 92/120
# 11/11 [==============================] - 0s 7ms/step - loss: 0.5110 - accuracy: 0.7968 - val_loss: 0.5402 - val_accuracy: 0.7806
# Epoch 93/120
# 11/11 [==============================] - 0s 9ms/step - loss: 0.5158 - accuracy: 0.7958 - val_loss: 0.5368 - val_accuracy: 0.7742
# Epoch 94/120
# 11/11 [==============================] - 0s 6ms/step - loss: 0.5161 - accuracy: 0.7879 - val_loss: 0.5410 - val_accuracy: 0.7839
# Epoch 95/120
# 11/11 [==============================] - 0s 6ms/step - loss: 0.5144 - accuracy: 0.7922 - val_loss: 0.5388 - val_accuracy: 0.7774
# Epoch 96/120
# 11/11 [==============================] - 0s 6ms/step - loss: 0.5099 - accuracy: 0.7936 - val_loss: 0.5378 - val_accuracy: 0.7903
# Epoch 97/120
# 11/11 [==============================] - 0s 10ms/step - loss: 0.5144 - accuracy: 0.7979 - val_loss: 0.5364 - val_accuracy: 0.7774
# Epoch 98/120
# 11/11 [==============================] - 0s 8ms/step - loss: 0.5125 - accuracy: 0.7979 - val_loss: 0.5354 - val_accuracy: 0.7742
# Epoch 99/120
# 11/11 [==============================] - 0s 8ms/step - loss: 0.5105 - accuracy: 0.7872 - val_loss: 0.5387 - val_accuracy: 0.7839
# Epoch 100/120
# 11/11 [==============================] - 0s 8ms/step - loss: 0.5012 - accuracy: 0.7965 - val_loss: 0.5370 - val_accuracy: 0.7774
# Epoch 101/120
# 11/11 [==============================] - 0s 6ms/step - loss: 0.5138 - accuracy: 0.7940 - val_loss: 0.5399 - val_accuracy: 0.7806
# Epoch 102/120
# 11/11 [==============================] - 0s 6ms/step - loss: 0.5149 - accuracy: 0.7929 - val_loss: 0.5428 - val_accuracy: 0.7806
# Epoch 103/120
# 11/11 [==============================] - 0s 10ms/step - loss: 0.5102 - accuracy: 0.7947 - val_loss: 0.5399 - val_accuracy: 0.7806
# Epoch 104/120
# 11/11 [==============================] - 0s 9ms/step - loss: 0.5136 - accuracy: 0.7940 - val_loss: 0.5387 - val_accuracy: 0.7806
# Epoch 105/120
# 11/11 [==============================] - 0s 7ms/step - loss: 0.5046 - accuracy: 0.7997 - val_loss: 0.5383 - val_accuracy: 0.7774
# Epoch 106/120
# 11/11 [==============================] - 0s 6ms/step - loss: 0.5141 - accuracy: 0.8040 - val_loss: 0.5413 - val_accuracy: 0.7839
# Epoch 107/120
# 11/11 [==============================] - 0s 7ms/step - loss: 0.4904 - accuracy: 0.8019 - val_loss: 0.5400 - val_accuracy: 0.7806
# Epoch 108/120
# 11/11 [==============================] - 0s 8ms/step - loss: 0.5037 - accuracy: 0.7961 - val_loss: 0.5357 - val_accuracy: 0.7839
# Epoch 109/120
# 11/11 [==============================] - 0s 9ms/step - loss: 0.4979 - accuracy: 0.8033 - val_loss: 0.5369 - val_accuracy: 0.7806
# Epoch 110/120
# 11/11 [==============================] - 0s 7ms/step - loss: 0.4975 - accuracy: 0.8098 - val_loss: 0.5400 - val_accuracy: 0.7839
# Epoch 111/120
# 11/11 [==============================] - 0s 7ms/step - loss: 0.4980 - accuracy: 0.8015 - val_loss: 0.5406 - val_accuracy: 0.7871
# Epoch 112/120
# 11/11 [==============================] - 0s 6ms/step - loss: 0.4952 - accuracy: 0.7950 - val_loss: 0.5469 - val_accuracy: 0.7839
# Epoch 113/120
# 11/11 [==============================] - 0s 9ms/step - loss: 0.5020 - accuracy: 0.8015 - val_loss: 0.5457 - val_accuracy: 0.7774
# Epoch 114/120
# 11/11 [==============================] - 0s 8ms/step - loss: 0.5059 - accuracy: 0.7972 - val_loss: 0.5469 - val_accuracy: 0.7774
# Epoch 115/120
# 11/11 [==============================] - 0s 8ms/step - loss: 0.5004 - accuracy: 0.7990 - val_loss: 0.5469 - val_accuracy: 0.7806
# Epoch 116/120
# 11/11 [==============================] - 0s 7ms/step - loss: 0.4909 - accuracy: 0.8033 - val_loss: 0.5433 - val_accuracy: 0.7806
# Epoch 117/120
# 11/11 [==============================] - 0s 8ms/step - loss: 0.4863 - accuracy: 0.8047 - val_loss: 0.5372 - val_accuracy: 0.7839
# Epoch 118/120
# 11/11 [==============================] - 0s 7ms/step - loss: 0.4872 - accuracy: 0.8026 - val_loss: 0.5397 - val_accuracy: 0.7774
# Epoch 119/120
# 11/11 [==============================] - 0s 8ms/step - loss: 0.4924 - accuracy: 0.8029 - val_loss: 0.5413 - val_accuracy: 0.7871
# Epoch 120/120
# 11/11 [==============================] - 0s 9ms/step - loss: 0.4913 - accuracy: 0.7979 - val_loss: 0.5389 - val_accuracy: 0.7871
# 42/42 [==============================] - 0s 2ms/step
# Test loss: 0.5659698247909546
# Test accuracy: 0.7718373537063599
# Accuracy: 0.7718373493975904
# Precision: 0.7585600802419163
# Recall: 0.7718373493975904
# F1 Score: 0.762259309230676

# %% [markdown]
# ## Apply Random Forest

# %%
rf_model = RandomForestClassifier(n_estimators=1000, random_state=1)

rf_model.fit(X_train, y_train)

y_pred = rf_model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print('Accuracy:', accuracy)
print('Precision:', precision)
print('Recall:', recall)
print('F1 Score:', f1)
# Out:
# Accuracy: 0.7131024096385542
# Precision: 0.8311646962792022
# Recall: 0.7131024096385542
# F1 Score: 0.7377040558362125
