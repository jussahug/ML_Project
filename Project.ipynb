# %% [markdown]
# # Import các thư viện cần thiết

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.ensemble import RandomForestClassifier
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint
from prettytable import PrettyTable
import joblib

# %% [markdown]
# # Import data

# %%
# from google.colab import drive
# drive.mount('/content/gdrive')
# %cd '/content/gdrive/MyDrive/Project'

# %%
# !pip install ucimlrepo
from ucimlrepo import fetch_ucirepo

# fetch dataset
predict_students_dropout_and_academic_success = fetch_ucirepo(id=697)

# data (as pandas dataframes)
X = predict_students_dropout_and_academic_success.data.features
y = predict_students_dropout_and_academic_success.data.targets

# metadata
print(predict_students_dropout_and_academic_success.metadata)

# variable information
print(predict_students_dropout_and_academic_success.variables)
# Out:
# Requirement already satisfied: ucimlrepo in /usr/local/lib/python3.10/dist-packages (0.0.7)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ucimlrepo) (2.0.3)
# Requirement already satisfied: certifi>=2020.12.5 in /usr/local/lib/python3.10/dist-packages (from ucimlrepo) (2024.7.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->ucimlrepo) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->ucimlrepo) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->ucimlrepo) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->ucimlrepo) (1.25.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->ucimlrepo) (1.16.0)
# {'uci_id': 697, 'name': "Predict Students' Dropout and Academic Success", 'repository_url': 'https://archive.ics.uci.edu/dataset/697/predict+students+dropout+and+academic+success', 'data_url': 'https://archive.ics.uci.edu/static/public/697/data.csv', 'abstract': "A dataset created from a higher education institution (acquired from several disjoint databases) related to students enrolled in different undergraduate degrees, such as agronomy, design, education, nursing, journalism, management, social service, and technologies.\nThe dataset includes information known at the time of student enrollment (academic path, demographics, and social-economic factors) and the students' academic performance at the end of the first and second semesters. \nThe data is used to build classification models to predict students' dropout and academic sucess. The problem is formulated as a three category classification task, in which there is a strong imbalance towards one of the classes.", 'area': 'Social Science', 'tasks': ['Classification'], 'characteristics': ['Tabular'], 'num_instances': 4424, 'num_features': 36, 'feature_types': ['Real', 'Categorical', 'Integer'], 'demographics': ['Marital Status', 'Education Level', 'Nationality', 'Occupation', 'Gender', 'Age'], 'target_col': ['Target'], 'index_col': None, 'has_missing_values': 'no', 'missing_values_symbol': None, 'year_of_dataset_creation': 2021, 'last_updated': 'Mon Feb 26 2024', 'dataset_doi': '10.24432/C5MC89', 'creators': ['Valentim Realinho', 'Mónica Vieira Martins', 'Jorge Machado', 'Luís Baptista'], 'intro_paper': {'title': "Early prediction of student's performance in higher education: a case study", 'authors': 'Mónica V. Martins, Daniel Tolledo, Jorge Machado, Luís M. T. Baptista, and Valentim Realinho', 'published_in': 'Trends and Applications in Information Systems and Technologies', 'year': 2021, 'url': 'http://www.worldcist.org/2021/', 'doi': 'http://www.doi.org/10.1007/978-3-030-72657-7_16'}, 'additional_info': {'summary': None, 'purpose': 'The dataset was created in a project that aims to contribute to the reduction of academic dropout and failure in higher education, by using machine learning techniques to identify students at risk at an early stage of their academic path, so that strategies to support them can be put into place. \n\nThe dataset includes information known at the time of student enrollment – academic path, demographics, and social-economic factors. \n\nThe problem is formulated as a three category classification task (dropout, enrolled, and graduate) at the end of the normal duration of the course. \n', 'funded_by': 'This dataset is supported by program SATDAP - Capacitação da Administração Pública under grant POCI-05-5762-FSE-000191, Portugal.', 'instances_represent': 'Each instance is a student', 'recommended_data_splits': 'The dataset was used, in our project, with a data split of 80% for training and 20% for test.', 'sensitive_data': None, 'preprocessing_description': 'We performed a rigorous data preprocessing to handle data from anomalies, unexplainable outliers, and missing values.', 'variable_info': None, 'citation': 'If you use this dataset in experiments for a scientific publication, please kindly cite our paper: \nM.V.Martins, D. Tolledo, J. Machado, L. M.T. Baptista, V.Realinho. (2021) "Early prediction of student’s performance in higher education: a case study" Trends and Applications in Information Systems and Technologies, vol.1, in Advances in Intelligent Systems and Computing series. Springer. DOI: 10.1007/978-3-030-72657-7_16'}}
#                                               name     role         type  \
# 0                                   Marital Status  Feature      Integer
# 1                                 Application mode  Feature      Integer
# 2                                Application order  Feature      Integer
# 3                                           Course  Feature      Integer
# 4                       Daytime/evening attendance  Feature      Integer
# 5                           Previous qualification  Feature      Integer
# 6                   Previous qualification (grade)  Feature   Continuous
# 7                                      Nacionality  Feature      Integer
# 8                           Mother's qualification  Feature      Integer
# 9                           Father's qualification  Feature      Integer
# 10                             Mother's occupation  Feature      Integer
# 11                             Father's occupation  Feature      Integer
# 12                                 Admission grade  Feature   Continuous
# 13                                       Displaced  Feature      Integer
# 14                       Educational special needs  Feature      Integer
# 15                                          Debtor  Feature      Integer
# 16                         Tuition fees up to date  Feature      Integer
# 17                                          Gender  Feature      Integer
# 18                              Scholarship holder  Feature      Integer
# 19                               Age at enrollment  Feature      Integer
# 20                                   International  Feature      Integer
# 21             Curricular units 1st sem (credited)  Feature      Integer
# 22             Curricular units 1st sem (enrolled)  Feature      Integer
# 23          Curricular units 1st sem (evaluations)  Feature      Integer
# 24             Curricular units 1st sem (approved)  Feature      Integer
# 25                Curricular units 1st sem (grade)  Feature      Integer
# 26  Curricular units 1st sem (without evaluations)  Feature      Integer
# 27             Curricular units 2nd sem (credited)  Feature      Integer
# 28             Curricular units 2nd sem (enrolled)  Feature      Integer
# 29          Curricular units 2nd sem (evaluations)  Feature      Integer
# 30             Curricular units 2nd sem (approved)  Feature      Integer
# 31                Curricular units 2nd sem (grade)  Feature      Integer
# 32  Curricular units 2nd sem (without evaluations)  Feature      Integer
# 33                               Unemployment rate  Feature   Continuous
# 34                                  Inflation rate  Feature   Continuous
# 35                                             GDP  Feature   Continuous
# 36                                          Target   Target  Categorical
#
#         demographic                                        description units  \
# 0    Marital Status  1 – single 2 – married 3 – widower 4 – divorce...  None
# 1              None  1 - 1st phase - general contingent 2 - Ordinan...  None
# 2              None  Application order (between 0 - first choice; a...  None
# 3              None  33 - Biofuel Production Technologies 171 - Ani...  None
# 4              None                            1 – daytime 0 - evening  None
# 5   Education Level  1 - Secondary education 2 - Higher education -...  None
# 6              None  Grade of previous qualification (between 0 and...  None
# 7       Nationality  1 - Portuguese; 2 - German; 6 - Spanish; 11 - ...  None
# 8   Education Level  1 - Secondary Education - 12th Year of Schooli...  None
# 9   Education Level  1 - Secondary Education - 12th Year of Schooli...  None
# 10       Occupation  0 - Student 1 - Representatives of the Legisla...  None
# 11       Occupation  0 - Student 1 - Representatives of the Legisla...  None
# 12             None                Admission grade (between 0 and 200)  None
# 13             None                                     1 – yes 0 – no  None
# 14             None                                     1 – yes 0 – no  None
# 15             None                                     1 – yes 0 – no  None
# 16             None                                     1 – yes 0 – no  None
# 17           Gender                                1 – male 0 – female  None
# 18             None                                     1 – yes 0 – no  None
# 19              Age                       Age of studend at enrollment  None
# 20             None                                     1 – yes 0 – no  None
# 21             None  Number of curricular units credited in the 1st...  None
# 22             None  Number of curricular units enrolled in the 1st...  None
# 23             None  Number of evaluations to curricular units in t...  None
# 24             None  Number of curricular units approved in the 1st...  None
# 25             None  Grade average in the 1st semester (between 0 a...  None
# 26             None  Number of curricular units without evalutions ...  None
# 27             None  Number of curricular units credited in the 2nd...  None
# 28             None  Number of curricular units enrolled in the 2nd...  None
# 29             None  Number of evaluations to curricular units in t...  None
# 30             None  Number of curricular units approved in the 2nd...  None
# 31             None  Grade average in the 2nd semester (between 0 a...  None
# 32             None  Number of curricular units without evalutions ...  None
# 33             None                              Unemployment rate (%)  None
# 34             None                                 Inflation rate (%)  None
# 35             None                                                GDP  None
# 36             None  Target. The problem is formulated as a three c...  None
#
#    missing_values
# 0              no
# 1              no
# 2              no
# 3              no
# 4              no
# 5              no
# 6              no
# 7              no
# 8              no
# 9              no
# 10             no
# 11             no
# 12             no
# 13             no
# 14             no
# 15             no
# 16             no
# 17             no
# 18             no
# 19             no
# 20             no
# 21             no
# 22             no
# 23             no
# 24             no
# 25             no
# 26             no
# 27             no
# 28             no
# 29             no
# 30             no
# 31             no
# 32             no
# 33             no
# 34             no
# 35             no
# 36             no

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train)
y_test = label_encoder.transform(y_test)

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

print("Shape of y_train (after to_categorical):", y_train.shape)
print("Shape of y_test (after to_categorical):", y_test.shape)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=1)
# Out:
# Shape of y_train (after to_categorical): (3539, 3)
# Shape of y_test (after to_categorical): (885, 3)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)

# %% [markdown]
# ## Apply Neural Network

# %%
model = Sequential()
model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dense(3, activation='softmax'))


model.summary()

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

checkpoint_filepath = 'best_model.h5'
model_checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)

history = model.fit(X_train, y_train, batch_size=256, epochs=120, validation_data=(X_val, y_val), callbacks=[model_checkpoint_callback])

best_model = keras.models.load_model(checkpoint_filepath)

y_pred = best_model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_test_classes = np.argmax(y_test, axis=1)

accuracy_NN = accuracy_score(y_test_classes, y_pred_classes)
precision_NN = precision_score(y_test_classes, y_pred_classes, average='weighted')
recall_NN = recall_score(y_test_classes, y_pred_classes, average='weighted')
f1_NN = f1_score(y_test_classes, y_pred_classes, average='weighted')

score = best_model.evaluate(X_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
print('Accuracy:', accuracy_NN)
print('Precision:', precision_NN)
print('Recall:', recall_NN)
print('F1 Score:', f1_NN)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                2368
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 6723 (26.26 KB)
# Trainable params: 6723 (26.26 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/120
# 11/13 [========================>.....] - ETA: 0s - loss: 1.0932 - accuracy: 0.4304
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 13/13 [==============================] - 13s 308ms/step - loss: 1.0768 - accuracy: 0.4487 - val_loss: 0.8623 - val_accuracy: 0.6667
# Epoch 2/120
# 13/13 [==============================] - 1s 64ms/step - loss: 0.9248 - accuracy: 0.6126 - val_loss: 0.7416 - val_accuracy: 0.7062
# Epoch 3/120
# 13/13 [==============================] - 1s 74ms/step - loss: 0.8319 - accuracy: 0.6619 - val_loss: 0.6792 - val_accuracy: 0.7288
# Epoch 4/120
# 13/13 [==============================] - 1s 66ms/step - loss: 0.7779 - accuracy: 0.6841 - val_loss: 0.6363 - val_accuracy: 0.7514
# Epoch 5/120
# 13/13 [==============================] - 1s 64ms/step - loss: 0.7422 - accuracy: 0.6980 - val_loss: 0.6039 - val_accuracy: 0.7740
# Epoch 6/120
# 13/13 [==============================] - 1s 44ms/step - loss: 0.7402 - accuracy: 0.6989 - val_loss: 0.5892 - val_accuracy: 0.7853
# Epoch 7/120
# 13/13 [==============================] - 1s 49ms/step - loss: 0.7032 - accuracy: 0.7165 - val_loss: 0.5750 - val_accuracy: 0.7938
# Epoch 8/120
# 13/13 [==============================] - 1s 41ms/step - loss: 0.7027 - accuracy: 0.7209 - val_loss: 0.5639 - val_accuracy: 0.7938
# Epoch 9/120
# 13/13 [==============================] - 1s 64ms/step - loss: 0.6889 - accuracy: 0.7199 - val_loss: 0.5658 - val_accuracy: 0.7910
# Epoch 10/120
# 13/13 [==============================] - 1s 78ms/step - loss: 0.6643 - accuracy: 0.7344 - val_loss: 0.5582 - val_accuracy: 0.7910
# Epoch 11/120
# 13/13 [==============================] - 1s 61ms/step - loss: 0.6659 - accuracy: 0.7287 - val_loss: 0.5525 - val_accuracy: 0.7825
# Epoch 12/120
# 13/13 [==============================] - 0s 38ms/step - loss: 0.6575 - accuracy: 0.7319 - val_loss: 0.5534 - val_accuracy: 0.7825
# Epoch 13/120
# 13/13 [==============================] - 1s 116ms/step - loss: 0.6548 - accuracy: 0.7350 - val_loss: 0.5542 - val_accuracy: 0.7797
# Epoch 14/120
# 13/13 [==============================] - 1s 85ms/step - loss: 0.6391 - accuracy: 0.7381 - val_loss: 0.5452 - val_accuracy: 0.7797
# Epoch 15/120
# 13/13 [==============================] - 1s 50ms/step - loss: 0.6426 - accuracy: 0.7469 - val_loss: 0.5488 - val_accuracy: 0.7797
# Epoch 16/120
# 13/13 [==============================] - 0s 29ms/step - loss: 0.6335 - accuracy: 0.7476 - val_loss: 0.5452 - val_accuracy: 0.7825
# Epoch 17/120
# 13/13 [==============================] - 0s 30ms/step - loss: 0.6209 - accuracy: 0.7604 - val_loss: 0.5445 - val_accuracy: 0.7825
# Epoch 18/120
# 13/13 [==============================] - 1s 42ms/step - loss: 0.6212 - accuracy: 0.7513 - val_loss: 0.5388 - val_accuracy: 0.7910
# Epoch 19/120
# 13/13 [==============================] - 1s 56ms/step - loss: 0.6183 - accuracy: 0.7501 - val_loss: 0.5438 - val_accuracy: 0.7768
# Epoch 20/120
# 13/13 [==============================] - 0s 33ms/step - loss: 0.6108 - accuracy: 0.7507 - val_loss: 0.5348 - val_accuracy: 0.7797
# Epoch 21/120
# 13/13 [==============================] - 0s 29ms/step - loss: 0.6054 - accuracy: 0.7557 - val_loss: 0.5437 - val_accuracy: 0.7825
# Epoch 22/120
# 13/13 [==============================] - 1s 43ms/step - loss: 0.6036 - accuracy: 0.7582 - val_loss: 0.5322 - val_accuracy: 0.7881
# Epoch 23/120
# 13/13 [==============================] - 0s 27ms/step - loss: 0.6003 - accuracy: 0.7614 - val_loss: 0.5362 - val_accuracy: 0.7797
# Epoch 24/120
# 13/13 [==============================] - 0s 20ms/step - loss: 0.5923 - accuracy: 0.7598 - val_loss: 0.5309 - val_accuracy: 0.7881
# Epoch 25/120
# 13/13 [==============================] - 0s 22ms/step - loss: 0.6017 - accuracy: 0.7545 - val_loss: 0.5314 - val_accuracy: 0.7825
# Epoch 26/120
# 13/13 [==============================] - 0s 24ms/step - loss: 0.5938 - accuracy: 0.7604 - val_loss: 0.5352 - val_accuracy: 0.7768
# Epoch 27/120
# 13/13 [==============================] - 0s 19ms/step - loss: 0.6023 - accuracy: 0.7579 - val_loss: 0.5275 - val_accuracy: 0.7825
# Epoch 28/120
# 13/13 [==============================] - 0s 19ms/step - loss: 0.5928 - accuracy: 0.7639 - val_loss: 0.5352 - val_accuracy: 0.7797
# Epoch 29/120
# 13/13 [==============================] - 0s 20ms/step - loss: 0.5900 - accuracy: 0.7620 - val_loss: 0.5336 - val_accuracy: 0.7881
# Epoch 30/120
# 13/13 [==============================] - 0s 12ms/step - loss: 0.5821 - accuracy: 0.7592 - val_loss: 0.5354 - val_accuracy: 0.7768
# Epoch 31/120
# 13/13 [==============================] - 0s 16ms/step - loss: 0.5864 - accuracy: 0.7614 - val_loss: 0.5315 - val_accuracy: 0.7938
# Epoch 32/120
# 13/13 [==============================] - 0s 27ms/step - loss: 0.5834 - accuracy: 0.7695 - val_loss: 0.5297 - val_accuracy: 0.7881
# Epoch 33/120
# 13/13 [==============================] - 0s 21ms/step - loss: 0.5877 - accuracy: 0.7598 - val_loss: 0.5320 - val_accuracy: 0.7825
# Epoch 34/120
# 13/13 [==============================] - 0s 19ms/step - loss: 0.5778 - accuracy: 0.7673 - val_loss: 0.5284 - val_accuracy: 0.7853
# Epoch 35/120
# 13/13 [==============================] - 0s 22ms/step - loss: 0.5784 - accuracy: 0.7714 - val_loss: 0.5308 - val_accuracy: 0.7881
# Epoch 36/120
# 13/13 [==============================] - 0s 30ms/step - loss: 0.5729 - accuracy: 0.7755 - val_loss: 0.5281 - val_accuracy: 0.7825
# Epoch 37/120
# 13/13 [==============================] - 0s 16ms/step - loss: 0.5638 - accuracy: 0.7783 - val_loss: 0.5254 - val_accuracy: 0.7910
# Epoch 38/120
# 13/13 [==============================] - 0s 16ms/step - loss: 0.5672 - accuracy: 0.7743 - val_loss: 0.5292 - val_accuracy: 0.7797
# Epoch 39/120
# 13/13 [==============================] - 0s 13ms/step - loss: 0.5663 - accuracy: 0.7699 - val_loss: 0.5337 - val_accuracy: 0.7853
# Epoch 40/120
# 13/13 [==============================] - 0s 20ms/step - loss: 0.5711 - accuracy: 0.7705 - val_loss: 0.5249 - val_accuracy: 0.7881
# Epoch 41/120
# 13/13 [==============================] - 0s 24ms/step - loss: 0.5707 - accuracy: 0.7689 - val_loss: 0.5234 - val_accuracy: 0.7938
# Epoch 42/120
# 13/13 [==============================] - 0s 19ms/step - loss: 0.5645 - accuracy: 0.7793 - val_loss: 0.5301 - val_accuracy: 0.7825
# Epoch 43/120
# 13/13 [==============================] - 0s 26ms/step - loss: 0.5620 - accuracy: 0.7711 - val_loss: 0.5233 - val_accuracy: 0.7966
# Epoch 44/120
# 13/13 [==============================] - 0s 29ms/step - loss: 0.5577 - accuracy: 0.7727 - val_loss: 0.5274 - val_accuracy: 0.7797
# Epoch 45/120
# 13/13 [==============================] - 0s 29ms/step - loss: 0.5629 - accuracy: 0.7730 - val_loss: 0.5307 - val_accuracy: 0.7825
# Epoch 46/120
# 13/13 [==============================] - 0s 21ms/step - loss: 0.5620 - accuracy: 0.7755 - val_loss: 0.5253 - val_accuracy: 0.7853
# Epoch 47/120
# 13/13 [==============================] - 0s 25ms/step - loss: 0.5563 - accuracy: 0.7736 - val_loss: 0.5221 - val_accuracy: 0.7881
# Epoch 48/120
# 13/13 [==============================] - 0s 29ms/step - loss: 0.5554 - accuracy: 0.7761 - val_loss: 0.5277 - val_accuracy: 0.7853
# Epoch 49/120
# 13/13 [==============================] - 0s 27ms/step - loss: 0.5507 - accuracy: 0.7896 - val_loss: 0.5267 - val_accuracy: 0.7881
# Epoch 50/120
# 13/13 [==============================] - 0s 36ms/step - loss: 0.5487 - accuracy: 0.7805 - val_loss: 0.5281 - val_accuracy: 0.7881
# Epoch 51/120
# 13/13 [==============================] - 0s 35ms/step - loss: 0.5525 - accuracy: 0.7796 - val_loss: 0.5316 - val_accuracy: 0.7853
# Epoch 52/120
# 13/13 [==============================] - 0s 28ms/step - loss: 0.5430 - accuracy: 0.7774 - val_loss: 0.5218 - val_accuracy: 0.7853
# Epoch 53/120
# 13/13 [==============================] - 0s 35ms/step - loss: 0.5398 - accuracy: 0.7777 - val_loss: 0.5290 - val_accuracy: 0.7797
# Epoch 54/120
# 13/13 [==============================] - 0s 26ms/step - loss: 0.5469 - accuracy: 0.7849 - val_loss: 0.5304 - val_accuracy: 0.7853
# Epoch 55/120
# 13/13 [==============================] - 0s 25ms/step - loss: 0.5482 - accuracy: 0.7815 - val_loss: 0.5263 - val_accuracy: 0.7853
# Epoch 56/120
# 13/13 [==============================] - 0s 35ms/step - loss: 0.5421 - accuracy: 0.7846 - val_loss: 0.5289 - val_accuracy: 0.7853
# Epoch 57/120
# 13/13 [==============================] - 1s 46ms/step - loss: 0.5435 - accuracy: 0.7802 - val_loss: 0.5242 - val_accuracy: 0.7881
# Epoch 58/120
# 13/13 [==============================] - 0s 14ms/step - loss: 0.5375 - accuracy: 0.7824 - val_loss: 0.5358 - val_accuracy: 0.7825
# Epoch 59/120
# 13/13 [==============================] - 0s 11ms/step - loss: 0.5411 - accuracy: 0.7849 - val_loss: 0.5292 - val_accuracy: 0.7768
# Epoch 60/120
# 13/13 [==============================] - 0s 17ms/step - loss: 0.5411 - accuracy: 0.7849 - val_loss: 0.5282 - val_accuracy: 0.7825
# Epoch 61/120
# 13/13 [==============================] - 0s 20ms/step - loss: 0.5362 - accuracy: 0.7846 - val_loss: 0.5362 - val_accuracy: 0.7797
# Epoch 62/120
# 13/13 [==============================] - 0s 24ms/step - loss: 0.5390 - accuracy: 0.7890 - val_loss: 0.5297 - val_accuracy: 0.7797
# Epoch 63/120
# 13/13 [==============================] - 0s 30ms/step - loss: 0.5393 - accuracy: 0.7837 - val_loss: 0.5307 - val_accuracy: 0.7797
# Epoch 64/120
# 13/13 [==============================] - 0s 17ms/step - loss: 0.5385 - accuracy: 0.7871 - val_loss: 0.5323 - val_accuracy: 0.7768
# Epoch 65/120
# 13/13 [==============================] - 0s 20ms/step - loss: 0.5352 - accuracy: 0.7890 - val_loss: 0.5352 - val_accuracy: 0.7825
# Epoch 66/120
# 13/13 [==============================] - 0s 32ms/step - loss: 0.5282 - accuracy: 0.7865 - val_loss: 0.5318 - val_accuracy: 0.7853
# Epoch 67/120
# 13/13 [==============================] - 0s 24ms/step - loss: 0.5364 - accuracy: 0.7849 - val_loss: 0.5331 - val_accuracy: 0.7853
# Epoch 68/120
# 13/13 [==============================] - 0s 25ms/step - loss: 0.5353 - accuracy: 0.7878 - val_loss: 0.5385 - val_accuracy: 0.7740
# Epoch 69/120
# 13/13 [==============================] - 0s 20ms/step - loss: 0.5317 - accuracy: 0.7837 - val_loss: 0.5401 - val_accuracy: 0.7740
# Epoch 70/120
# 13/13 [==============================] - 0s 11ms/step - loss: 0.5329 - accuracy: 0.7890 - val_loss: 0.5342 - val_accuracy: 0.7825
# Epoch 71/120
# 13/13 [==============================] - 0s 24ms/step - loss: 0.5261 - accuracy: 0.7940 - val_loss: 0.5357 - val_accuracy: 0.7881
# Epoch 72/120
# 13/13 [==============================] - 0s 29ms/step - loss: 0.5299 - accuracy: 0.7884 - val_loss: 0.5433 - val_accuracy: 0.7797
# Epoch 73/120
# 13/13 [==============================] - 0s 25ms/step - loss: 0.5184 - accuracy: 0.7987 - val_loss: 0.5358 - val_accuracy: 0.7910
# Epoch 74/120
# 13/13 [==============================] - 0s 23ms/step - loss: 0.5290 - accuracy: 0.7878 - val_loss: 0.5397 - val_accuracy: 0.7881
# Epoch 75/120
# 13/13 [==============================] - 0s 27ms/step - loss: 0.5158 - accuracy: 0.7896 - val_loss: 0.5417 - val_accuracy: 0.7881
# Epoch 76/120
# 13/13 [==============================] - 0s 29ms/step - loss: 0.5221 - accuracy: 0.7959 - val_loss: 0.5431 - val_accuracy: 0.7853
# Epoch 77/120
# 13/13 [==============================] - 0s 28ms/step - loss: 0.5170 - accuracy: 0.7909 - val_loss: 0.5465 - val_accuracy: 0.7797
# Epoch 78/120
# 13/13 [==============================] - 0s 27ms/step - loss: 0.5171 - accuracy: 0.7896 - val_loss: 0.5404 - val_accuracy: 0.7938
# Epoch 79/120
# 13/13 [==============================] - 0s 14ms/step - loss: 0.5314 - accuracy: 0.7937 - val_loss: 0.5426 - val_accuracy: 0.7881
# Epoch 80/120
# 13/13 [==============================] - 0s 21ms/step - loss: 0.5121 - accuracy: 0.7947 - val_loss: 0.5415 - val_accuracy: 0.7881
# Epoch 81/120
# 13/13 [==============================] - 0s 27ms/step - loss: 0.5158 - accuracy: 0.7906 - val_loss: 0.5427 - val_accuracy: 0.7825
# Epoch 82/120
# 13/13 [==============================] - 0s 25ms/step - loss: 0.5113 - accuracy: 0.7972 - val_loss: 0.5504 - val_accuracy: 0.7853
# Epoch 83/120
# 13/13 [==============================] - 0s 25ms/step - loss: 0.5167 - accuracy: 0.7943 - val_loss: 0.5418 - val_accuracy: 0.7881
# Epoch 84/120
# 13/13 [==============================] - 0s 19ms/step - loss: 0.5146 - accuracy: 0.7896 - val_loss: 0.5402 - val_accuracy: 0.7825
# Epoch 85/120
# 13/13 [==============================] - 0s 33ms/step - loss: 0.5207 - accuracy: 0.7950 - val_loss: 0.5466 - val_accuracy: 0.7825
# Epoch 86/120
# 13/13 [==============================] - 0s 17ms/step - loss: 0.5166 - accuracy: 0.7931 - val_loss: 0.5501 - val_accuracy: 0.7938
# Epoch 87/120
# 13/13 [==============================] - 0s 13ms/step - loss: 0.5207 - accuracy: 0.7987 - val_loss: 0.5460 - val_accuracy: 0.7825
# Epoch 88/120
# 13/13 [==============================] - 0s 23ms/step - loss: 0.5151 - accuracy: 0.7943 - val_loss: 0.5529 - val_accuracy: 0.7881
# Epoch 89/120
# 13/13 [==============================] - 0s 23ms/step - loss: 0.5075 - accuracy: 0.7978 - val_loss: 0.5484 - val_accuracy: 0.7881
# Epoch 90/120
# 13/13 [==============================] - 0s 24ms/step - loss: 0.4993 - accuracy: 0.7987 - val_loss: 0.5468 - val_accuracy: 0.7881
# Epoch 91/120
# 13/13 [==============================] - 0s 20ms/step - loss: 0.5126 - accuracy: 0.7975 - val_loss: 0.5509 - val_accuracy: 0.7853
# Epoch 92/120
# 13/13 [==============================] - 0s 32ms/step - loss: 0.5116 - accuracy: 0.8028 - val_loss: 0.5456 - val_accuracy: 0.7853
# Epoch 93/120
# 13/13 [==============================] - 0s 31ms/step - loss: 0.5125 - accuracy: 0.7912 - val_loss: 0.5468 - val_accuracy: 0.7910
# Epoch 94/120
# 13/13 [==============================] - 1s 41ms/step - loss: 0.5168 - accuracy: 0.7934 - val_loss: 0.5464 - val_accuracy: 0.7910
# Epoch 95/120
# 13/13 [==============================] - 0s 30ms/step - loss: 0.5068 - accuracy: 0.7984 - val_loss: 0.5461 - val_accuracy: 0.7910
# Epoch 96/120
# 13/13 [==============================] - 0s 31ms/step - loss: 0.5099 - accuracy: 0.7956 - val_loss: 0.5482 - val_accuracy: 0.7825
# Epoch 97/120
# 13/13 [==============================] - 0s 28ms/step - loss: 0.5028 - accuracy: 0.7965 - val_loss: 0.5445 - val_accuracy: 0.7966
# Epoch 98/120
# 13/13 [==============================] - 0s 38ms/step - loss: 0.5069 - accuracy: 0.7947 - val_loss: 0.5433 - val_accuracy: 0.7938
# Epoch 99/120
# 13/13 [==============================] - 0s 24ms/step - loss: 0.5050 - accuracy: 0.8025 - val_loss: 0.5482 - val_accuracy: 0.7910
# Epoch 100/120
# 13/13 [==============================] - 0s 35ms/step - loss: 0.5012 - accuracy: 0.7994 - val_loss: 0.5444 - val_accuracy: 0.7966
# Epoch 101/120
# 13/13 [==============================] - 0s 22ms/step - loss: 0.5105 - accuracy: 0.7972 - val_loss: 0.5509 - val_accuracy: 0.7881
# Epoch 102/120
# 13/13 [==============================] - 0s 26ms/step - loss: 0.5021 - accuracy: 0.8013 - val_loss: 0.5491 - val_accuracy: 0.7853
# Epoch 103/120
# 13/13 [==============================] - 0s 22ms/step - loss: 0.5018 - accuracy: 0.7931 - val_loss: 0.5498 - val_accuracy: 0.7797
# Epoch 104/120
# 13/13 [==============================] - 0s 14ms/step - loss: 0.5047 - accuracy: 0.8025 - val_loss: 0.5521 - val_accuracy: 0.7797
# Epoch 105/120
# 13/13 [==============================] - 0s 14ms/step - loss: 0.5003 - accuracy: 0.8003 - val_loss: 0.5494 - val_accuracy: 0.7910
# Epoch 106/120
# 13/13 [==============================] - 0s 10ms/step - loss: 0.5044 - accuracy: 0.7981 - val_loss: 0.5473 - val_accuracy: 0.7910
# Epoch 107/120
# 13/13 [==============================] - 0s 11ms/step - loss: 0.5087 - accuracy: 0.7965 - val_loss: 0.5529 - val_accuracy: 0.7881
# Epoch 108/120
# 13/13 [==============================] - 0s 15ms/step - loss: 0.5060 - accuracy: 0.7991 - val_loss: 0.5430 - val_accuracy: 0.7910
# Epoch 109/120
# 13/13 [==============================] - 0s 17ms/step - loss: 0.5034 - accuracy: 0.7975 - val_loss: 0.5533 - val_accuracy: 0.7910
# Epoch 110/120
# 13/13 [==============================] - 0s 10ms/step - loss: 0.4975 - accuracy: 0.8035 - val_loss: 0.5478 - val_accuracy: 0.7910
# Epoch 111/120
# 13/13 [==============================] - 0s 9ms/step - loss: 0.5061 - accuracy: 0.7943 - val_loss: 0.5551 - val_accuracy: 0.7938
# Epoch 112/120
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5112 - accuracy: 0.7984 - val_loss: 0.5491 - val_accuracy: 0.7825
# Epoch 113/120
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5070 - accuracy: 0.8031 - val_loss: 0.5530 - val_accuracy: 0.7825
# Epoch 114/120
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4921 - accuracy: 0.8066 - val_loss: 0.5501 - val_accuracy: 0.7881
# Epoch 115/120
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4939 - accuracy: 0.8016 - val_loss: 0.5494 - val_accuracy: 0.7881
# Epoch 116/120
# 13/13 [==============================] - 0s 8ms/step - loss: 0.4967 - accuracy: 0.7987 - val_loss: 0.5588 - val_accuracy: 0.7881
# Epoch 117/120
# 13/13 [==============================] - 0s 12ms/step - loss: 0.5002 - accuracy: 0.7997 - val_loss: 0.5548 - val_accuracy: 0.7825
# Epoch 118/120
# 13/13 [==============================] - 0s 16ms/step - loss: 0.4890 - accuracy: 0.8000 - val_loss: 0.5499 - val_accuracy: 0.7853
# Epoch 119/120
# 13/13 [==============================] - 0s 13ms/step - loss: 0.4944 - accuracy: 0.7991 - val_loss: 0.5596 - val_accuracy: 0.7825
# Epoch 120/120
# 13/13 [==============================] - 0s 8ms/step - loss: 0.4886 - accuracy: 0.8019 - val_loss: 0.5530 - val_accuracy: 0.7881
# 28/28 [==============================] - 0s 1ms/step
# Test loss: 0.5782936811447144
# Test accuracy: 0.7570621371269226
# Accuracy: 0.7570621468926554
# Precision: 0.7401082915721688
# Recall: 0.7570621468926554
# F1 Score: 0.7420985667432692

# %% [markdown]
# ## Apply Random Forest

# %%
#Xuất performance của mô hình
def export_metrics(y_pred, y_test):
  acc = accuracy_score(y_test, y_pred)
  pre = precision_score(y_test, y_pred, average='macro')
  re = recall_score(y_test, y_pred, average='macro')
  f1 = f1_score(y_test, y_pred, average='macro')
  return acc, pre, re, f1

# %%
rf_model = RandomForestClassifier(n_estimators=1000, random_state=1)

rf_model.fit(X_train, y_train)

y_pred = rf_model.predict(X_test)

accuracy_RF = accuracy_score(y_test, y_pred)
precision_RF = precision_score(y_test, y_pred, average='weighted')
recall_RF = recall_score(y_test, y_pred, average='weighted')
f1_RF = f1_score(y_test, y_pred, average='weighted')

print('Accuracy:', accuracy_RF)
print('Precision:', precision_RF)
print('Recall:', recall_RF)
print('F1 Score:', f1_RF)

file_name_joblib = "RF_joblib.joblib"

joblib.dump(rf_model, file_name_joblib)

loaded_model_joblib = joblib.load(file_name_joblib)
y_pred1 = loaded_model_joblib.predict(X_test)
export_metrics(y_pred1, y_test)

export_metrics(y_pred1, y_test)
file_name_joblib_compressed = "RF_joblib_compressed.joblib"

joblib.dump(rf_model, file_name_joblib_compressed,compress=3)
loaded_model_joblib_compressed = joblib.load(file_name_joblib_compressed)
y_pred2 = loaded_model_joblib_compressed.predict(X_test)
export_metrics(y_pred2, y_test)
# Out:
# Accuracy: 0.7152542372881356
# Precision: 0.8296444558548968
# Recall: 0.7152542372881356
# F1 Score: 0.7386030608692983
# (0.7152542372881356,
#  0.8118042458855074,
#  0.6029470289381125,
#  0.6504788027194689)

# %% [markdown]
# ## Table

# %%
table = PrettyTable()
table.field_names = ["Metric", "Neural Network", "Random Forest"]

table.add_row(["Accuracy", accuracy_NN, accuracy_RF])
table.add_row(["Precision", precision_NN, precision_RF])
table.add_row(["Recall", recall_NN, recall_RF])
table.add_row(["F1 Score", f1_NN, f1_RF])
print(table)
# Out:
# +-----------+--------------------+--------------------+
# |   Metric  |   Neural Network   |   Random Forest    |
# +-----------+--------------------+--------------------+
# |  Accuracy | 0.7570621468926554 | 0.7152542372881356 |
# | Precision | 0.7401082915721688 | 0.8296444558548968 |
# |   Recall  | 0.7570621468926554 | 0.7152542372881356 |
# |  F1 Score | 0.7420985667432692 | 0.7386030608692983 |
# +-----------+--------------------+--------------------+
